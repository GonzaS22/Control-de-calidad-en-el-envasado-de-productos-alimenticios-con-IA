# %% [markdown]
# # Imporación de paquetes y montaje de Google Drive

# %%
#Importación de paquetes
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt
import numpy as np

import torch.nn as nn
import torch.nn.functional as F

import torch.optim as optim

#Inicialización la GPU proporcionada por Google Colab
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# !nvidia-smi
# Out:
# Tue Aug 27 22:42:18 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   66C    P0              31W /  70W |    457MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %%
#Activación del acceso a Google Drive
from google.colab import drive
drive.mount('/content/drive')

#Definición de una ruta donde se encuentra la base de datos con las imágenes
PATH = '/content/drive/MyDrive/Nube /UNL_Automatizacion y Robotica/Proyecto_final_de_la_carrera/imagenes_frascos_2'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Funciones

# %%
#Función para levantar las imagenes desde una carpeta principal
#compuesta por subcarpetas divididas por las diferentes clases.
def cargar_imagenes(main_folder, image_size = (1080, 1920), train_test_ratio = [0.8, 0.2], image_batch_size = 16):

    #Definición de una transformación
    transform = transforms.Compose([
        transforms.Resize(image_size),  #Ajusta el tamaño de las imágenes
        transforms.ToTensor()  #Convierte las imágenes en tensores de PyTorch
    ])

    #Creación de un dataset con todas las imágenes separadas por clases
    dataset = ImageFolder(main_folder, transform=transform)

    #Creación de los datasets de entrenamiento y prueba
    train_dataset_f, test_dataset_f = torch.utils.data.random_split(dataset,
                                                                train_test_ratio,
                                                                generator=torch.Generator().manual_seed(42))

    #Creación de los datasets definitivos de entrenamiento y validación a partir
    #del dataset de entrenamiento
    train_dataset_f, val_dataset_f = torch.utils.data.random_split(train_dataset_f,
                                                                train_test_ratio,
                                                                generator=torch.Generator().manual_seed(42))

    #Devolución los datasets creados
    return train_dataset_f, val_dataset_f, test_dataset_f

# %%
#Función para convertir los datasets en dataloaders
def crear_dataloader(dataset_user, images_bach_size = 16, shuffle_user=True):

    #Creación de un dataloader a partir del dataset disponible
    dataloader_user = DataLoader(dataset_user,
                                     batch_size=images_bach_size,
                                     shuffle=shuffle_user)

    #Devolución del dataloader creado
    return dataloader_user

# %%
#Función para mostrar imagenes
def imshow(img):
    #Se revierte la normalización colocando los valores de los pixeles en el
    #rango de [0, 1]
    img = img / 2 + 0.5

    #Se transforma el tensor de imágenes en un arreglo de numpy
    npimg = img.numpy()

    #Se reordena el arreglo anterior al formato (altura, anchura, canales)
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

    #Se muestran las imágenes
    plt.show()

# %% [markdown]
# # Visualización de datos

# %%
#Denición del tamaño de lote
batch_size = 16

#Creación de los datasets para entrenamiento, validación y prueba
train_dataset, val_dataset, test_dataset = cargar_imagenes(PATH, (224, 224))


#Creación de los dataloader para entrenamiento, validación y prueba
train_dataloader = crear_dataloader(train_dataset)
val_dataloader = crear_dataloader(val_dataset)
test_dataloader = crear_dataloader(test_dataset)


#Creación de una tupla con los nombres de las clases
classes = ('correcto', 'vacio')

#Transformación del dataloader de entrenamiento en un iterador
dataiter = iter(train_dataloader)
#Obtención de las imágenes y las etiquetas por separado
images, labels = next(dataiter)

#Se muestran las imágenes de entrenamiento en una cuadrícula
imshow(torchvision.utils.make_grid(images))
#Se imprimen las etiquetas reales de las imágenes
print('       '.join(f'{classes[labels[j]]:5s}' for j in range(batch_size)))
# Out:
# vacio       vacio       correcto       vacio       vacio       vacio       correcto       correcto       correcto       correcto       vacio       vacio       correcto       correcto       vacio       vacio

# %%
#Transformación del dataloader de entrenamiento en un iterador
dataiter = iter(test_dataloader)
#Obtención de las imágenes y las etiquetas por separado
images, labels = next(dataiter)

#Se muestran las imágenes de entrenamiento en una cuadrícula
imshow(torchvision.utils.make_grid(images))
#Se imprimen las etiquetas reales de las imágenes
print('       '.join(f'{classes[labels[j]]:5s}' for j in range(batch_size)))
# Out:
# vacio       correcto       correcto       correcto       vacio       correcto       correcto       vacio       vacio       correcto       correcto       vacio       vacio       correcto       vacio       correcto

# %% [markdown]
# # Modelo neuronal

# %%
#Creación del modelo neuronal
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 16, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(16, 32, 3)
        #self.pool = nn.MaxPool2d(2, 2)
        self.conv3 = nn.Conv2d(32, 64, 3)
        self.conv4 = nn.Conv2d(64, 64, 3)
        self.conv5 = nn.Conv2d(64, 128, 3)
        self.fc1 = nn.Linear(3200, 128)
        self.fc2 = nn.Linear(128, 8)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = self.pool(F.relu(self.conv4(x)))
        x = self.pool(F.relu(self.conv5(x)))
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

#Inicialización de la red
net = Net()

# %%
#Definición de un criterio de error o función de pérdida
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# # Entrenamiento

# %%
#Función para evaluar el rendimiento de una red neuronal midiendo su accuracy y
#error medio
def calculate_accuracy(net, dataloader):
    #Inicialización en 0 de variables para contar cantidad de predicciones
    #correctas, total de predicciones y la acumulación del error
    correct = 0
    total = 0
    total_loss = 0

    #Definición de la función de pérdida utilizada
    criterion = nn.CrossEntropyLoss()

    #Desactivando el cálculo de gradientes
    with torch.no_grad():
        #Iterando a travez de los elementos del dataloader
        for data in dataloader:
            #Se obtienen las imágenes de entrada con sus etiquetas reales
            inputs, labels = data
            #Obtención de las predicciones realizadas por la red para las entradas
            outputs = net(inputs.to("cuda"))
            #Selección del valor de predicción de clase más alto para cada salida
            _, predicted = torch.max(outputs.data, 1)
            #Actualización del número total de muestras evaluadas
            total += labels.size(0)
            #Si la predicción fue correcta, aumenta en 1 un contador
            correct += (predicted == labels.to("cuda")).sum().item()
            #Cálculo de error o pérdida para el lote actual
            loss = criterion(outputs, labels.to("cuda"))
            #Se suma el error del lote actual al total de error
            total_loss += loss.item()

    #Cálculo de accuracy
    accuracy = 100 * correct / total
    #Cálculo del error medio
    error = total_loss / total

    #Se devuelven los valores de accuracy y error medio calculado
    return accuracy, error

# %%
#Creación de una estrctura para guardar métricas
measures = {
            'trn_loss': [],
            'trn_acc': [],
            'val_loss': [],
            'val_acc': []
           }

# %%
#Definición de variables
counter = 0       #Contador para chequear en validación
best_loss = 1E6   #Variable para el mejor error
best_acc = 0      #Variable para el mejor accuracy
fold = 0          #Contador de epocas de entrenamiento

#Inicialización de la red neuronal
net = Net()

#Se mueve el modelo a la GPU
net = net.to("cuda")

#Definición del optimizador
optimizer = optim.Adam(net.parameters(), lr=1e-4)


#El entrenamiento durará 1o epocas o hasta que se alcanse el límite del
#contador, indicando que el modelo está memorizando los datos
while (fold < 25) and (counter < 15):
    #Reinicio de los valores de error actual, contador y mejor epoca para este fold
    running_loss = 0.0
    counter = 0
    best_epoch = 0

    #Se itera sobre el dataloader de entrenamiento
    for i, data in enumerate(train_dataloader, 0):

        #Obtención de las entradas y las etiquetas por separado
        inputs, labels = data

        #Se ponen en cero o reinicial los gradientes de los parámetros
        optimizer.zero_grad()

        #Paso hacia adelante calculando las salidas de la red
        outputs = net(inputs.to("cuda"))
        #Cálculo entre las salidas de la red y las etiquetas verdaderas
        loss = criterion(outputs, labels.to("cuda"))
        #Paso hacia atrás calculando el gradiente de la pérdida respecto a los parámetros
        loss.backward()
        #Actualización de los parámetros de la red con el optimizador
        optimizer.step()

        #Se acumula el error actual a una suma de error total
        running_loss += loss.item()

        #Se calcula el accuracy y el error medio para el dataloader de
        #entrenamiento y validación
        train_accuracy, train_loss = calculate_accuracy(net, train_dataloader)
        val_accuracy, val_loss = calculate_accuracy(net, val_dataloader)

        #Guardado de las métricas obtenidas en un diccionario
        measures['trn_loss'].append(train_loss)
        measures['trn_acc'].append(train_accuracy)
        measures['val_loss'].append(val_loss)
        measures['val_acc'].append(val_accuracy)

        #Impresión de las métricas por cada época de entrenamiento
        if (i%1) == 0:
            print(f'Epoch {i}: trn_loss: {train_loss:.5}\t val_loss: {val_loss:.5}\t trn_acc: {train_accuracy}\t val_acc: {val_accuracy}\t counter: {counter}')


        #=================================
        #Si el error actual es menor al mejor error registrado
        if (val_loss < best_loss):

            #Actualización del mejor error al error actual
            best_loss = val_loss
            #Guardado de la mejor época
            best_epoch = i
            #Actualización del mejor valor de accuracy
            best_acc = val_accuracy

            #Guardado del modelo actual como un diccionario
            best_model = net.state_dict()
            counter = 0  #Reinicio del contador

        #Si esta época no fue mejor que la anterior
        else:
            counter += 1 #Aumenta el contador en 1

    #=================================
    #Al finalizar una etapa de entranamiento, se muestan los mejores resultados
    print('-' * 30)
    print(f'Fold {fold + 1}:')
    print(f'Best Epoch: {best_epoch:}')
    print(f'Best Loss: {best_loss:.2f}')
    print(f'Best Accuracy: {best_acc:.2f}')
    print(f'Counter: {counter:}')
    print('=' * 30)

    #Se aumenta el contador de etapas
    fold += 1


#Al finalizar el entrenamiento se muestra un mensaje
print('Finished Training')

#Definición de la ruta donde se guarda el modelo entrenado
model_path = '/content/drive/MyDrive/Nube /UNL_Automatizacion y Robotica/Proyecto_final_de_la_carrera/best_model.pth'

#Guardado del modelo entrenado en el archivo
torch.save(best_model, model_path)

#Se imprime un mensaje anunciando que se guardo el modelo
print('=' * 30)
print("Modelo guardado")
# Out:
# Epoch 0: trn_loss: 0.13241	 val_loss: 0.13196	 trn_acc: 0.0	 val_acc: 0.0	 counter: 0
# Epoch 1: trn_loss: 0.13206	 val_loss: 0.1316	 trn_acc: 0.0	 val_acc: 0.0	 counter: 0
# Epoch 2: trn_loss: 0.13173	 val_loss: 0.13125	 trn_acc: 0.0	 val_acc: 0.0	 counter: 0
# Epoch 3: trn_loss: 0.1314	 val_loss: 0.13092	 trn_acc: 0.0	 val_acc: 0.0	 counter: 0
# ------------------------------
# Fold 1:
# Best Epoch: 3
# Best Loss: 0.13
# Best Accuracy: 0.00
# Counter: 0
# ==============================
# Epoch 0: trn_loss: 0.13111	 val_loss: 0.13063	 trn_acc: 0.0	 val_acc: 0.0	 counter: 0
# Epoch 1: trn_loss: 0.13083	 val_loss: 0.13034	 trn_acc: 0.0	 val_acc: 0.0	 counter: 0
# Epoch 2: trn_loss: 0.13054	 val_loss: 0.13004	 trn_acc: 0.0	 val_acc: 0.0	 counter: 0
# Epoch 3: trn_loss: 0.13023	 val_loss: 0.12973	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# ------------------------------
# Fold 2:
# Best Epoch: 3
# Best Loss: 0.13
# Best Accuracy: 56.25
# Counter: 0
# ==============================
# Epoch 0: trn_loss: 0.12989	 val_loss: 0.12938	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 1: trn_loss: 0.12952	 val_loss: 0.12899	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 2: trn_loss: 0.12911	 val_loss: 0.12858	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 3: trn_loss: 0.12864	 val_loss: 0.1281	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# ------------------------------
# Fold 3:
# Best Epoch: 3
# Best Loss: 0.13
# Best Accuracy: 56.25
# Counter: 0
# ==============================
# Epoch 0: trn_loss: 0.12811	 val_loss: 0.12756	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 1: trn_loss: 0.12749	 val_loss: 0.12694	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 2: trn_loss: 0.12679	 val_loss: 0.12622	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 3: trn_loss: 0.12597	 val_loss: 0.1254	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# ------------------------------
# Fold 4:
# Best Epoch: 3
# Best Loss: 0.13
# Best Accuracy: 56.25
# Counter: 0
# ==============================
# Epoch 0: trn_loss: 0.12504	 val_loss: 0.12445	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 1: trn_loss: 0.12396	 val_loss: 0.12335	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 2: trn_loss: 0.12272	 val_loss: 0.12209	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 3: trn_loss: 0.1213	 val_loss: 0.12065	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# ------------------------------
# Fold 5:
# Best Epoch: 3
# Best Loss: 0.12
# Best Accuracy: 56.25
# Counter: 0
# ==============================
# Epoch 0: trn_loss: 0.11966	 val_loss: 0.11899	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 1: trn_loss: 0.11777	 val_loss: 0.11708	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 2: trn_loss: 0.11559	 val_loss: 0.11487	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 3: trn_loss: 0.11307	 val_loss: 0.11232	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# ------------------------------
# Fold 6:
# Best Epoch: 3
# Best Loss: 0.11
# Best Accuracy: 56.25
# Counter: 0
# ==============================
# Epoch 0: trn_loss: 0.11019	 val_loss: 0.1094	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 1: trn_loss: 0.10691	 val_loss: 0.10609	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 2: trn_loss: 0.10322	 val_loss: 0.10237	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 3: trn_loss: 0.099096	 val_loss: 0.098194	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# ------------------------------
# Fold 7:
# Best Epoch: 3
# Best Loss: 0.10
# Best Accuracy: 56.25
# Counter: 0
# ==============================
# Epoch 0: trn_loss: 0.094506	 val_loss: 0.093544	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 1: trn_loss: 0.089491	 val_loss: 0.088442	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 2: trn_loss: 0.084103	 val_loss: 0.082943	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 3: trn_loss: 0.078428	 val_loss: 0.07717	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# ------------------------------
# Fold 8:
# Best Epoch: 3
# Best Loss: 0.08
# Best Accuracy: 56.25
# Counter: 0
# ==============================
# Epoch 0: trn_loss: 0.072637	 val_loss: 0.07129	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 1: trn_loss: 0.066981	 val_loss: 0.065489	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 2: trn_loss: 0.061756	 val_loss: 0.06006	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 3: trn_loss: 0.057125	 val_loss: 0.055354	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# ------------------------------
# Fold 9:
# Best Epoch: 3
# Best Loss: 0.06
# Best Accuracy: 56.25
# Counter: 0
# ==============================
# Epoch 0: trn_loss: 0.053464	 val_loss: 0.051497	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 1: trn_loss: 0.050484	 val_loss: 0.04853	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 2: trn_loss: 0.048197	 val_loss: 0.046299	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 3: trn_loss: 0.046348	 val_loss: 0.044662	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# ------------------------------
# Fold 10:
# Best Epoch: 3
# Best Loss: 0.04
# Best Accuracy: 56.25
# Counter: 0
# ==============================
# Epoch 0: trn_loss: 0.04487	 val_loss: 0.04356	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 1: trn_loss: 0.043855	 val_loss: 0.042946	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 2: trn_loss: 0.043246	 val_loss: 0.042945	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 3: trn_loss: 0.043079	 val_loss: 0.043199	 trn_acc: 70.3125	 val_acc: 56.25	 counter: 0
# ------------------------------
# Fold 11:
# Best Epoch: 2
# Best Loss: 0.04
# Best Accuracy: 56.25
# Counter: 1
# ==============================
# Epoch 0: trn_loss: 0.043392	 val_loss: 0.044083	 trn_acc: 50.0	 val_acc: 43.75	 counter: 0
# Epoch 1: trn_loss: 0.043343	 val_loss: 0.044135	 trn_acc: 50.0	 val_acc: 43.75	 counter: 1
# Epoch 2: trn_loss: 0.043127	 val_loss: 0.043886	 trn_acc: 50.0	 val_acc: 43.75	 counter: 2
# Epoch 3: trn_loss: 0.042878	 val_loss: 0.043569	 trn_acc: 50.0	 val_acc: 43.75	 counter: 3
# ------------------------------
# Fold 12:
# Best Epoch: 0
# Best Loss: 0.04
# Best Accuracy: 56.25
# Counter: 4
# ==============================
# Epoch 0: trn_loss: 0.042622	 val_loss: 0.043235	 trn_acc: 50.0	 val_acc: 43.75	 counter: 0
# Epoch 1: trn_loss: 0.042365	 val_loss: 0.042894	 trn_acc: 50.0	 val_acc: 43.75	 counter: 1
# Epoch 2: trn_loss: 0.042001	 val_loss: 0.042303	 trn_acc: 73.4375	 val_acc: 56.25	 counter: 0
# Epoch 3: trn_loss: 0.041659	 val_loss: 0.041371	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# ------------------------------
# Fold 13:
# Best Epoch: 3
# Best Loss: 0.04
# Best Accuracy: 56.25
# Counter: 0
# ==============================
# Epoch 0: trn_loss: 0.041751	 val_loss: 0.04089	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 1: trn_loss: 0.041668	 val_loss: 0.040737	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 2: trn_loss: 0.041599	 val_loss: 0.040582	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 3: trn_loss: 0.041506	 val_loss: 0.040382	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# ------------------------------
# Fold 14:
# Best Epoch: 3
# Best Loss: 0.04
# Best Accuracy: 56.25
# Counter: 0
# ==============================
# Epoch 0: trn_loss: 0.041029	 val_loss: 0.040221	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 1: trn_loss: 0.040973	 val_loss: 0.040036	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 2: trn_loss: 0.040565	 val_loss: 0.039894	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 3: trn_loss: 0.04019	 val_loss: 0.04009	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# ------------------------------
# Fold 15:
# Best Epoch: 2
# Best Loss: 0.04
# Best Accuracy: 56.25
# Counter: 1
# ==============================
# Epoch 0: trn_loss: 0.040062	 val_loss: 0.040492	 trn_acc: 100.0	 val_acc: 100.0	 counter: 0
# Epoch 1: trn_loss: 0.039887	 val_loss: 0.04049	 trn_acc: 93.75	 val_acc: 87.5	 counter: 1
# Epoch 2: trn_loss: 0.039618	 val_loss: 0.04023	 trn_acc: 95.3125	 val_acc: 87.5	 counter: 2
# Epoch 3: trn_loss: 0.039388	 val_loss: 0.040094	 trn_acc: 93.75	 val_acc: 87.5	 counter: 3
# ------------------------------
# Fold 16:
# Best Epoch: 0
# Best Loss: 0.04
# Best Accuracy: 56.25
# Counter: 4
# ==============================
# Epoch 0: trn_loss: 0.039708	 val_loss: 0.041006	 trn_acc: 51.5625	 val_acc: 43.75	 counter: 0
# Epoch 1: trn_loss: 0.038788	 val_loss: 0.03943	 trn_acc: 100.0	 val_acc: 93.75	 counter: 1
# Epoch 2: trn_loss: 0.038537	 val_loss: 0.038285	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 3: trn_loss: 0.038419	 val_loss: 0.037989	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# ------------------------------
# Fold 17:
# Best Epoch: 3
# Best Loss: 0.04
# Best Accuracy: 56.25
# Counter: 0
# ==============================
# Epoch 0: trn_loss: 0.037962	 val_loss: 0.03786	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 1: trn_loss: 0.03758	 val_loss: 0.037874	 trn_acc: 100.0	 val_acc: 100.0	 counter: 0
# Epoch 2: trn_loss: 0.03731	 val_loss: 0.03744	 trn_acc: 100.0	 val_acc: 100.0	 counter: 1
# Epoch 3: trn_loss: 0.036978	 val_loss: 0.037188	 trn_acc: 100.0	 val_acc: 100.0	 counter: 0
# ------------------------------
# Fold 18:
# Best Epoch: 3
# Best Loss: 0.04
# Best Accuracy: 100.00
# Counter: 0
# ==============================
# Epoch 0: trn_loss: 0.036613	 val_loss: 0.037134	 trn_acc: 100.0	 val_acc: 100.0	 counter: 0
# Epoch 1: trn_loss: 0.03639	 val_loss: 0.036414	 trn_acc: 100.0	 val_acc: 100.0	 counter: 0
# Epoch 2: trn_loss: 0.036315	 val_loss: 0.035998	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 3: trn_loss: 0.035587	 val_loss: 0.035778	 trn_acc: 100.0	 val_acc: 100.0	 counter: 0
# ------------------------------
# Fold 19:
# Best Epoch: 3
# Best Loss: 0.04
# Best Accuracy: 100.00
# Counter: 0
# ==============================
# Epoch 0: trn_loss: 0.035126	 val_loss: 0.036105	 trn_acc: 100.0	 val_acc: 100.0	 counter: 0
# Epoch 1: trn_loss: 0.034932	 val_loss: 0.036398	 trn_acc: 95.3125	 val_acc: 87.5	 counter: 1
# Epoch 2: trn_loss: 0.035202	 val_loss: 0.037358	 trn_acc: 84.375	 val_acc: 56.25	 counter: 2
# Epoch 3: trn_loss: 0.034333	 val_loss: 0.036292	 trn_acc: 89.0625	 val_acc: 81.25	 counter: 3
# ------------------------------
# Fold 20:
# Best Epoch: 0
# Best Loss: 0.04
# Best Accuracy: 100.00
# Counter: 4
# ==============================
# Epoch 0: trn_loss: 0.033655	 val_loss: 0.035555	 trn_acc: 93.75	 val_acc: 87.5	 counter: 0
# Epoch 1: trn_loss: 0.032913	 val_loss: 0.034696	 trn_acc: 95.3125	 val_acc: 87.5	 counter: 0
# Epoch 2: trn_loss: 0.032113	 val_loss: 0.032808	 trn_acc: 100.0	 val_acc: 100.0	 counter: 0
# Epoch 3: trn_loss: 0.032362	 val_loss: 0.032208	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# ------------------------------
# Fold 21:
# Best Epoch: 3
# Best Loss: 0.03
# Best Accuracy: 56.25
# Counter: 0
# ==============================
# Epoch 0: trn_loss: 0.032861	 val_loss: 0.032128	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 1: trn_loss: 0.031976	 val_loss: 0.031424	 trn_acc: 50.0	 val_acc: 56.25	 counter: 0
# Epoch 2: trn_loss: 0.029752	 val_loss: 0.030343	 trn_acc: 100.0	 val_acc: 100.0	 counter: 0
# Epoch 3: trn_loss: 0.02877	 val_loss: 0.030824	 trn_acc: 100.0	 val_acc: 93.75	 counter: 0
# ------------------------------
# Fold 22:
# Best Epoch: 2
# Best Loss: 0.03
# Best Accuracy: 100.00
# Counter: 1
# ==============================
# Epoch 0: trn_loss: 0.029753	 val_loss: 0.033333	 trn_acc: 87.5	 val_acc: 68.75	 counter: 0
# Epoch 1: trn_loss: 0.027769	 val_loss: 0.030672	 trn_acc: 95.3125	 val_acc: 87.5	 counter: 1
# Epoch 2: trn_loss: 0.026286	 val_loss: 0.028044	 trn_acc: 100.0	 val_acc: 100.0	 counter: 2
# Epoch 3: trn_loss: 0.025467	 val_loss: 0.027133	 trn_acc: 100.0	 val_acc: 100.0	 counter: 0
# ------------------------------
# Fold 23:
# Best Epoch: 3
# Best Loss: 0.03
# Best Accuracy: 100.00
# Counter: 0
# ==============================
# Epoch 0: trn_loss: 0.024548	 val_loss: 0.026382	 trn_acc: 100.0	 val_acc: 100.0	 counter: 0
# Epoch 1: trn_loss: 0.023763	 val_loss: 0.026528	 trn_acc: 100.0	 val_acc: 93.75	 counter: 0
# Epoch 2: trn_loss: 0.022828	 val_loss: 0.025764	 trn_acc: 100.0	 val_acc: 93.75	 counter: 1
# Epoch 3: trn_loss: 0.021622	 val_loss: 0.023881	 trn_acc: 100.0	 val_acc: 100.0	 counter: 0
# ------------------------------
# Fold 24:
# Best Epoch: 3
# Best Loss: 0.02
# Best Accuracy: 100.00
# Counter: 0
# ==============================
# Epoch 0: trn_loss: 0.021747	 val_loss: 0.022614	 trn_acc: 100.0	 val_acc: 100.0	 counter: 0
# Epoch 1: trn_loss: 0.021292	 val_loss: 0.021885	 trn_acc: 100.0	 val_acc: 100.0	 counter: 0
# Epoch 2: trn_loss: 0.018725	 val_loss: 0.020671	 trn_acc: 100.0	 val_acc: 100.0	 counter: 0
# Epoch 3: trn_loss: 0.018125	 val_loss: 0.022196	 trn_acc: 100.0	 val_acc: 87.5	 counter: 0
# ------------------------------
# Fold 25:
# Best Epoch: 2
# Best Loss: 0.02
# Best Accuracy: 100.00
# Counter: 1
# ==============================
# Finished Training
# ==============================
# Modelo guardado

# %% [markdown]
# # Visualización de métricas:

# %%
#Creación de un gráfico doble
fig, ax = plt.subplots(1,2,figsize=(22,6))

#En el primer gráfico se muestran los valores de error para los dataloader de
#entrenamiento y validación
ax[0].plot(measures['trn_loss'], 'C3', label='trn')
ax[0].plot(measures['val_loss'], 'C4', label='val')
ax[0].set_title('Loss')
ax[0].set_xlabel('epochs')
ax[0].set_ylabel('CEL')
ax[0].grid(True)
ax[0].legend()

#En el segundo gráfico se muestran los valores de accuracy para los dataloader
#de entrenamiento y validación
ax[1].plot(measures['trn_acc'], 'C2', label='trn')
ax[1].plot(measures['val_acc'], 'C3', label='val')
ax[1].set_title('Accuracy')
ax[1].set_xlabel('epochs')
ax[1].set_ylabel('Acc')
ax[1].grid(True)
ax[1].legend();

# %% [markdown]
# # Prueba:

# %%
#Inicialización de la red
net = Net()
#Se carga en la red el mejor modelo obtenido
net.load_state_dict(best_model)
net = net.to("cuda")

#Cálculo del error y accuracy en test
test_accuracy, test_loss = calculate_accuracy(net, test_dataloader)

#Se imprimen en pantalla los resultados de error y accuracy en test
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# Test Loss: 0.0342
# Test Accuracy: 100.0000
